# %% [markdown]
# # Import Modules

# %%
# Dataframes module
import pandas
# Module containing all of the constant values
import Constants as const
# Path module
import glob
# Open Computer Vision module
import cv2
# Plotting module
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread
# Python debugger module
import pdb

# %% [markdown]
# # Examples of how the input images look like

# %%
image_limit = 5

image_list = list()

fig = figure()
# Read the first 5 image files and display them
for it, image_file in enumerate(glob.glob(const.TRAINING_IMAGE_DIR + '*.jpg')):
    if it >= image_limit:
        break
    a = fig.add_subplot(1, image_limit, it + 1)
    image = imread(image_file)
    imshow(image)
    axis('off')
